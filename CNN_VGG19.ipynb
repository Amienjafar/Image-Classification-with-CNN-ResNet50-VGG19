# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import random
import pandas as pd
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
# from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Dropout, BatchNormalization, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import datetime
global_start = datetime.datetime.now();
gpu_information = len(tf.config.list_physical_devices('GPU'))>0
print ("available" if gpu_information else "not available")
# Out:
# available

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Dataset

# %%
size = 128
def dataset_load(src_path, data):
  base = os.listdir(src_path)
  base.sort()

  for folder in base:
    images = os.listdir(os.path.join(src_path, folder))
    images.sort()
    print("Load class '{}' = {} images".format(folder, len(images)))
    
    for image in tqdm(images):
      label = folder
      try:
        img = cv2.imread(os.path.join(src_path, folder, image))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (size,size), cv2.INTER_AREA)
      except:
        continue
      
      data.append([np.array(img), np.array(label)])
    print()
  
  random.shuffle(data)
  return data

# %%
dataset = []
src_path = '/content/drive/MyDrive/Dataset/mangga/augmentasi4'
dataset = dataset_load(src_path, dataset)
# Out:
# Load class 'Class_I' = 1800 images
# 100%|██████████| 1800/1800 [00:33<00:00, 53.36it/s]
# Load class 'Class_II' = 1800 images
# 100%|██████████| 1800/1800 [00:35<00:00, 50.99it/s]
# Load class 'Ekstra_Class' = 1800 images
# 100%|██████████| 1800/1800 [00:39<00:00, 45.61it/s]

# %%
fig, ax = plt.subplots(3,3)
fig.set_size_inches(6,6)
for i in range(3):
  for j in range (3):
    sample = random.choice(range(len(dataset)))
    ax[i,j].imshow(dataset[sample][0])
    ax[i,j].set_title('Class: '+str(dataset[sample][1]))
    ax[i,j].axis('off')
plt.tight_layout()

# %% [markdown]
# # Split Dataset

# %%
x = np.array([i[0] for i in dataset]).reshape(-1,size,size,3)
y = np.array([i[1] for i in dataset])

# %%
# Membuat label tiap kelas
label = {
    'Ekstra_Class' : 0,
    'Class_I' : 1,
    'Class_II' : 2,
}
y = np.vectorize(label.get)(y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.85, stratify=y)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size=0.85, stratify=y_train)
x_train = x_train/128.0
x_test = x_test/128.0
x_val = x_val/128.0

test_sample = x_test.copy()

print('Training size\t: X = {}\ty = {}'.format(len(x_train), len(y_train)))
print('Validation size\t: X = {}\ty = {}'.format(len(x_val), len(y_val)))
print('Testing size\t: X = {}\ty = {}'.format(len(x_test), len(y_test)))
# Out:
# Training size	: X = 3901	y = 3901
# Validation size	: X = 689	y = 689
# Testing size	: X = 810	y = 810

# %% [markdown]
# # Classification Model

# %%
from tensorflow.keras.applications.vgg19 import VGG19
classification = VGG19(input_shape = (size, size, 3), weights = 'imagenet', include_top = False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step

# %%
for layer in classification.layers:
    layer.trainable = False

x = Flatten()(classification.output)
prediction = Dense(3, activation='softmax')(x)

model = Model(inputs=classification.input, outputs=prediction)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 128, 128, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 128, 128, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 64, 64, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 64, 64, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 64, 64, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 32, 32, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 32, 32, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 32, 32, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 16, 16, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 16, 16, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_conv4 (Conv2D)       (None, 8, 8, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 3)                 24579
#
# =================================================================
# Total params: 20,048,963
# Trainable params: 24,579
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(model=model, show_shapes=True)

# %% [markdown]
# # Optimizer

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # History Model Run

# %%
early_stop = EarlyStopping(monitor = 'val_loss' ,verbose = 1, patience = 10)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', patience=10, verbose=1, factor=0.1, min_lr=0.001)
# callbacks = [early_stop, reduce_lr]
callbacks = [early_stop]

# %%
history = model.fit(
    x_train, y_train,
    batch_size = 32,
    epochs = 50,
    validation_data = (x_val, y_val),
    callbacks=callbacks,
    # shuffle=True
    )

print(datetime.datetime.now()-global_start)
# Out:
# Epoch 1/50
# 122/122 [==============================] - 32s 168ms/step - loss: 0.5155 - accuracy: 0.7903 - val_loss: 0.3365 - val_accuracy: 0.8723
# Epoch 2/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.2987 - accuracy: 0.8931 - val_loss: 0.3014 - val_accuracy: 0.8853
# Epoch 3/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.2411 - accuracy: 0.9205 - val_loss: 0.2489 - val_accuracy: 0.9129
# Epoch 4/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.2020 - accuracy: 0.9359 - val_loss: 0.2225 - val_accuracy: 0.9173
# Epoch 5/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.1853 - accuracy: 0.9387 - val_loss: 0.2111 - val_accuracy: 0.9158
# Epoch 6/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.1653 - accuracy: 0.9482 - val_loss: 0.2224 - val_accuracy: 0.9245
# Epoch 7/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.1491 - accuracy: 0.9541 - val_loss: 0.1875 - val_accuracy: 0.9347
# Epoch 8/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.1344 - accuracy: 0.9572 - val_loss: 0.1745 - val_accuracy: 0.9361
# Epoch 9/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.1296 - accuracy: 0.9605 - val_loss: 0.2058 - val_accuracy: 0.9173
# Epoch 10/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.1208 - accuracy: 0.9626 - val_loss: 0.1928 - val_accuracy: 0.9231
# Epoch 11/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.1069 - accuracy: 0.9700 - val_loss: 0.1610 - val_accuracy: 0.9347
# Epoch 12/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0995 - accuracy: 0.9710 - val_loss: 0.1534 - val_accuracy: 0.9463
# Epoch 13/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.0925 - accuracy: 0.9731 - val_loss: 0.1529 - val_accuracy: 0.9536
# Epoch 14/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.0891 - accuracy: 0.9769 - val_loss: 0.1463 - val_accuracy: 0.9507
# Epoch 15/50
# 122/122 [==============================] - 17s 139ms/step - loss: 0.0768 - accuracy: 0.9803 - val_loss: 0.1460 - val_accuracy: 0.9463
# Epoch 16/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0813 - accuracy: 0.9777 - val_loss: 0.1385 - val_accuracy: 0.9550
# Epoch 17/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0694 - accuracy: 0.9844 - val_loss: 0.1329 - val_accuracy: 0.9507
# Epoch 18/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0654 - accuracy: 0.9872 - val_loss: 0.1325 - val_accuracy: 0.9521
# Epoch 19/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0596 - accuracy: 0.9874 - val_loss: 0.1417 - val_accuracy: 0.9492
# Epoch 20/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0602 - accuracy: 0.9872 - val_loss: 0.1639 - val_accuracy: 0.9361
# Epoch 21/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0584 - accuracy: 0.9864 - val_loss: 0.1318 - val_accuracy: 0.9579
# Epoch 22/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0514 - accuracy: 0.9905 - val_loss: 0.1604 - val_accuracy: 0.9361
# Epoch 23/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0505 - accuracy: 0.9921 - val_loss: 0.1216 - val_accuracy: 0.9608
# Epoch 24/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0467 - accuracy: 0.9926 - val_loss: 0.1192 - val_accuracy: 0.9579
# Epoch 25/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0458 - accuracy: 0.9941 - val_loss: 0.1181 - val_accuracy: 0.9608
# Epoch 26/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0426 - accuracy: 0.9921 - val_loss: 0.1214 - val_accuracy: 0.9579
# Epoch 27/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0395 - accuracy: 0.9949 - val_loss: 0.1148 - val_accuracy: 0.9637
# Epoch 28/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0373 - accuracy: 0.9941 - val_loss: 0.1168 - val_accuracy: 0.9623
# Epoch 29/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0340 - accuracy: 0.9959 - val_loss: 0.1234 - val_accuracy: 0.9536
# Epoch 30/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0321 - accuracy: 0.9974 - val_loss: 0.1159 - val_accuracy: 0.9637
# Epoch 31/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0314 - accuracy: 0.9969 - val_loss: 0.1147 - val_accuracy: 0.9608
# Epoch 32/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0303 - accuracy: 0.9967 - val_loss: 0.1117 - val_accuracy: 0.9637
# Epoch 33/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0282 - accuracy: 0.9972 - val_loss: 0.1229 - val_accuracy: 0.9623
# Epoch 34/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0296 - accuracy: 0.9972 - val_loss: 0.1223 - val_accuracy: 0.9594
# Epoch 35/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0262 - accuracy: 0.9985 - val_loss: 0.1388 - val_accuracy: 0.9507
# Epoch 36/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0258 - accuracy: 0.9977 - val_loss: 0.1149 - val_accuracy: 0.9637
# Epoch 37/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0264 - accuracy: 0.9972 - val_loss: 0.1124 - val_accuracy: 0.9594
# Epoch 38/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0245 - accuracy: 0.9979 - val_loss: 0.1387 - val_accuracy: 0.9521
# Epoch 39/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0220 - accuracy: 0.9985 - val_loss: 0.1242 - val_accuracy: 0.9608
# Epoch 40/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0187 - accuracy: 0.9987 - val_loss: 0.1104 - val_accuracy: 0.9608
# Epoch 41/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0198 - accuracy: 0.9987 - val_loss: 0.1182 - val_accuracy: 0.9623
# Epoch 42/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0177 - accuracy: 0.9992 - val_loss: 0.1111 - val_accuracy: 0.9623
# Epoch 43/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0179 - accuracy: 0.9990 - val_loss: 0.1113 - val_accuracy: 0.9637
# Epoch 44/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0196 - accuracy: 0.9985 - val_loss: 0.1106 - val_accuracy: 0.9652
# Epoch 45/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0150 - accuracy: 0.9995 - val_loss: 0.1145 - val_accuracy: 0.9608
# Epoch 46/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0147 - accuracy: 0.9997 - val_loss: 0.1163 - val_accuracy: 0.9579
# Epoch 47/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0160 - accuracy: 0.9992 - val_loss: 0.1150 - val_accuracy: 0.9579
# Epoch 48/50
# 122/122 [==============================] - 17s 138ms/step - loss: 0.0147 - accuracy: 0.9995 - val_loss: 0.1135 - val_accuracy: 0.9608
# Epoch 49/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0154 - accuracy: 0.9992 - val_loss: 0.1275 - val_accuracy: 0.9579
# Epoch 50/50
# 122/122 [==============================] - 17s 137ms/step - loss: 0.0131 - accuracy: 0.9997 - val_loss: 0.1140 - val_accuracy: 0.9623
# Epoch 50: early stopping
# 0:18:06.961297

# %%
def plot_training_history(history):
  plt.style.use('ggplot')
  fig = plt.figure(figsize=(16,6))
  
  plt.subplot(1,2,1)
  plt.plot(history.history['val_accuracy'], label='val acc')
  plt.plot(history.history['accuracy'], label='train acc')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Training and Validation Accuracy')
  plt.legend(['Validation Accuracy','Training Accuracy'], loc='lower right')
  
  plt.subplot(1,2,2)
  plt.plot(history.history['val_loss'], label='val loss')
  plt.plot(history.history['loss'], label='train loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.title('Training and Validation Loss')
  plt.legend(['Validation Loss','Training Loss'], loc='upper right')
  plt.show()

# %%
  plot_training_history(history)

# %%
print('Training Evaluation')
loss, acc = model.evaluate(x_train, y_train)
print('Loss\t\t:', loss)
print('Accuracy\t:', acc)
# Out:
# Training Evaluation
# 122/122 [==============================] - 14s 116ms/step - loss: 0.0111 - accuracy: 0.9997
# Loss		: 0.011120031587779522
# Accuracy	: 0.999743640422821

# %%
print('Validation Evaluation')
loss, acc = model.evaluate(x_val, y_val)
print('Loss\t\t:', loss)
print('Accuracy\t:', acc)
# Out:
# Validation Evaluation
# 22/22 [==============================] - 3s 115ms/step - loss: 0.1140 - accuracy: 0.9623
# Loss		: 0.1140136644244194
# Accuracy	: 0.9622641801834106

# %%
print('Testing Evaluation')
loss, acc = model.evaluate(x_test, y_test)
print('Loss\t\t:', loss)
print('Accuracy\t:', acc)
# Out:
# Testing Evaluation
# 26/26 [==============================] - 4s 167ms/step - loss: 0.0956 - accuracy: 0.9704
# Loss		: 0.09560272842645645
# Accuracy	: 0.970370352268219

# %%
y_pred = np.argmax(model.predict(x_test), axis=1)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       270
#            1       0.97      0.94      0.95       270
#            2       0.96      0.98      0.97       270
#
#     accuracy                           0.97       810
#    macro avg       0.97      0.97      0.97       810
# weighted avg       0.97      0.97      0.97       810

# %%
L = list(label)
c_matrix = confusion_matrix(y_test, y_pred)
c_matrix = pd.DataFrame(c_matrix, index=L, columns=L)

plt.figure(figsize = (10,8))
sns.heatmap(c_matrix, cmap='Blues', linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=L, yticklabels=L)

# %%
# model.save('/content/drive/MyDrive/Colab Notebooks/Model/vgg19_Adam_Baru.hdf5', overwrite=True, include_optimizer=True)
